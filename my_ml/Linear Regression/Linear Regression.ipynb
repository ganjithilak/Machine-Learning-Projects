# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("..\DATA\Ecommerce Customers.csv")

# %% [markdown]
# ## Get the Data
#
# Working with the Ecommerce Customers csv file from the company. It has Customer info, suchas Email, Address, and their color Avatar. Then it also has numerical value columns:
#
# * Avg. Session Length: Average session of in-store style advice sessions.
# * Time on App: Average time spent on App in minutes
# * Time on Website: Average time spent on Website in minutes
# * Length of Membership: How many years the customer has been a member.
#
# ** Reading in the Ecommerce Customers csv file as a DataFrame.**

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.describe().transpose()
# Out:
#                       count        mean        std         min         25%  \
# Avg. Session Length   500.0   33.053194   0.992563   29.532429   32.341822
# Time on App           500.0   12.052488   0.994216    8.508152   11.388153
# Time on Website       500.0   37.060445   1.010489   33.913847   36.349257
# Length of Membership  500.0    3.533462   0.999278    0.269901    2.930450
# Yearly Amount Spent   500.0  499.314038  79.314782  256.670582  445.038277
# total_time            500.0   49.112933   1.474820   43.970552   48.192759
#
#                              50%         75%         max
# Avg. Session Length    33.082008   33.711985   36.139662
# Time on App            11.983231   12.753850   15.126994
# Time on Website        37.069367   37.716432   40.005182
# Length of Membership    3.533975    4.126502    6.922689
# Yearly Amount Spent   498.887875  549.313828  765.518462
# total_time             49.056487   50.098144   53.112026

# %%
sns.jointplot(x='Time on Website',y='Yearly Amount Spent',data=df)

# %%
sns.jointplot(x='Time on App',y='Yearly Amount Spent',data=df)

# %%
df['total_time'] = df['Time on App']+df['Time on Website']

# %%
plt.figure(dpi=100)
sns.jointplot(x='total_time',y='Yearly Amount Spent',data=df)

# %%
sns.jointplot(x='Length of Membership',y='Yearly Amount Spent',data=df)

# %%
sns.scatterplot(x='Length of Membership',y='Yearly Amount Spent',data=df)
# Out:
# <AxesSubplot:xlabel='Length of Membership', ylabel='Yearly Amount Spent'>

# %%
sns.displot(x='Length of Membership',y='Yearly Amount Spent',data=df)

# %%
sns.lineplot(x='Length of Membership',y='Yearly Amount Spent',data=df)
# Out:
# <AxesSubplot:xlabel='Length of Membership', ylabel='Yearly Amount Spent'>

# %%
sns.lmplot(x='Length of Membership',y='Yearly Amount Spent',data=df)

# %%
df.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
# total_time                      -0.042730     0.730576         0.740701
#
#                       Length of Membership  Yearly Amount Spent  total_time
# Avg. Session Length               0.060247             0.355088   -0.042730
# Time on App                       0.029143             0.499328    0.730576
# Time on Website                  -0.047582            -0.002641    0.740701
# Length of Membership              1.000000             0.809084   -0.012955
# Yearly Amount Spent               0.809084             1.000000    0.334801
# total_time                       -0.012955             0.334801    1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent',
#        'total_time'],
#       dtype='object')

# %%
df.head(2)
# Out:
#                        Email                                         Address  \
# 0  mstephenson@fernandez.com    835 Frank Tunnel\nWrightmouth, MI 82180-9605
# 1          hduke@hotmail.com  4547 Archer Common\nDiazchester, CA 06566-8576
#
#       Avatar  Avg. Session Length  Time on App  Time on Website  \
# 0     Violet            34.497268    12.655651        39.577668
# 1  DarkGreen            31.926272    11.109461        37.268959
#
#    Length of Membership  Yearly Amount Spent  total_time
# 0              4.082621           587.951054   52.233319
# 1              2.664034           392.204933   48.378420

# %% [markdown]
# ## Spliting The data

# %%
X = df[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
y = df['Yearly Amount Spent']

# %%
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 249            33.780157    11.917636        36.844734              3.634996
# 433            34.278248    11.822722        36.308545              2.117383
# 19             32.617856    13.989593        37.190504              4.064549
# 322            33.264632    10.732131        36.145792              4.086566
# 332            33.144234    11.737041        37.935189              2.190132
# ..                   ...          ...              ...                   ...
# 106            32.291756    12.190474        36.152462              3.781823
# 270            34.006489    12.956277        38.655095              3.275734
# 348            31.812483    10.886921        34.897828              3.128639
# 435            32.259973    14.132893        37.023479              3.762070
# 102            32.425697    11.448902        37.580190              2.586968
#
# [400 rows x 4 columns]

# %%
y_train
# Out:
# 249    518.786483
# 433    434.144202
# 19     605.061039
# 322    478.262126
# 332    424.202827
#           ...
# 106    494.551861
# 270    540.995739
# 348    392.810345
# 435    571.216005
# 102    420.737673
# Name: Yearly Amount Spent, Length: 400, dtype: float64

# %%
X_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 361            32.077590    10.347877        39.045156              3.434560
# 73             32.808698    12.817113        37.031539              3.851579
# 374            31.447446    10.101632        38.043453              4.238296
# 155            32.449522    13.457725        37.238806              2.941411
# 104            31.389585    10.994224        38.074452              3.428860
# ..                   ...          ...              ...                   ...
# 347            33.769812    11.304462        37.833972              5.137817
# 86             33.877779    12.517666        37.151921              2.669942
# 75             32.049839    12.238057        38.730862              3.120569
# 438            32.149061    10.047315        37.181447              3.535088
# 15             30.737720    12.636606        36.213763              3.357847
#
# [100 rows x 4 columns]

# %%
y_test
# Out:
# 361    401.033135
# 73     534.777188
# 374    418.602742
# 155    503.978379
# 104    410.069611
#           ...
# 347    593.156401
# 86     487.379306
# 75     478.719357
# 438    392.992256
# 15     461.780742
# Name: Yearly Amount Spent, Length: 100, dtype: float64

# %% [markdown]
# ## Training The Model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
lr.predict([[30,10,39,4]])
# Out:
# array([371.17618397])

# %% [markdown]
# ## Evaluvating The Model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 8.558441885315231

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 109.86374118393985

# %%
mean_squared_error(y_test,y_pred,squared=False)
# Out:
# 10.481590584636468

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9778130629184127

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.01735755657515231

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9811320837551732

# %%
Adj_r2 = 1 - (1-r2_score(y_test, y_pred)) * (len(y)-1)/(len(y)-X.shape[1]-1)
Adj_r2
# Out:
# 0.980979615745114

# %% [markdown]
# ## Residuals
#
# **Ploting a histogram of the residuals and making sure it looks normally distributed. **

# %%
sns.distplot((y_test,y_pred),bins=50)
# Out:
# C:\Users\ganji thilak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot((y_test,y_pred),bins=50,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# # Thank you
